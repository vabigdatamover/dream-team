# %%
import pandas as pd

# %%
df = pd.read_csv('input/cities2.csv')
#df = pd.DataFrame({'a':['asds','asdds','asdsadsdas', 'asds']})
df.tail()
# Out:
#      City_ID        City  Cloudiness Country        Date  Humidity    Lat  \
# 543      543  san andres          68      PH  1528905632       100  13.32
# 544      544      muisne          92      EC  1528905633        84   0.61
# 545      545         ati          20      TD  1528905633        25  13.21
# 546      546    san luis           0      AR  1528905472        53 -33.30
# 547      546    san luis           0      AR  1528905472        53 -33.30
#
#         Lng  Max Temp  Wind Speed
# 543  122.68     83.47       22.64
# 544  -80.02     76.90        4.63
# 545   18.34    104.53        4.97
# 546  -66.34     42.43        2.62
# 547  -66.34     42.43        2.62

# %%
df['hash'] = pd.Series((hash(tuple(row)) for _, row in df.iterrows()))
#df['hash'] = df['City'].apply(hash)
df.tail()
# Out:
#      City_ID        City  Cloudiness Country        Date  Humidity    Lat  \
# 543      543  san andres          68      PH  1528905632       100  13.32
# 544      544      muisne          92      EC  1528905633        84   0.61
# 545      545         ati          20      TD  1528905633        25  13.21
# 546      546    san luis           0      AR  1528905472        53 -33.30
# 547      546    san luis           0      AR  1528905472        53 -33.30
#
#         Lng  Max Temp  Wind Speed                 hash
# 543  122.68     83.47       22.64  7532524177757841927
# 544  -80.02     76.90        4.63 -5554895458449913688
# 545   18.34    104.53        4.97 -3134491543899042054
# 546  -66.34     42.43        2.62  8719258850100896499
# 547  -66.34     42.43        2.62  8719258850100896499

# %%
df_nodupe = df[~df.duplicated()]

# %%
df_nodupe.tail()
# Out:
#      City_ID        City  Cloudiness Country        Date  Humidity    Lat  \
# 542      542      scalea          36      IT  1528905631       100  39.82
# 543      543  san andres          68      PH  1528905632       100  13.32
# 544      544      muisne          92      EC  1528905633        84   0.61
# 545      545         ati          20      TD  1528905633        25  13.21
# 546      546    san luis           0      AR  1528905472        53 -33.30
#
#         Lng  Max Temp  Wind Speed                 hash
# 542   15.79     70.06        5.30 -2726399573934779040
# 543  122.68     83.47       22.64  7532524177757841927
# 544  -80.02     76.90        4.63 -5554895458449913688
# 545   18.34    104.53        4.97 -3134491543899042054
# 546  -66.34     42.43        2.62  8719258850100896499

# %%
df_nodupe2 = df[df.duplicated()]

# %%
df_nodupe2.tail(5)
# Out:
#      City_ID      City  Cloudiness Country        Date  Humidity   Lat    Lng  \
# 547      546  san luis           0      AR  1528905472        53 -33.3 -66.34
#
#      Max Temp  Wind Speed                 hash
# 547     42.43        2.62  8719258850100896499
