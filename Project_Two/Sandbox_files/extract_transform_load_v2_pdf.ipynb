# %%
#pip install tabula-py
# Out:
#   File "<ipython-input-18-108c585a6179>", line 2
#     pip install pdfplumber
#               ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import glob
from tabula import read_pdf
from tabula import convert_into

# %% [markdown]
# ## Extract

# %%
#Only reads the first PDF page
#https://blog.chezo.uno/tabula-py-extract-table-from-pdf-into-python-dataframe-6c7acfa5f302
df = pd.concat(map(read_pdf, glob.glob('test_input' + '\*.pdf')))
#Extract All source code
#https://stackoverflow.com/questions/20906474/import-multiple-csv-files-into-pandas-and-concatenate-into-one-dataframe

# %%
df
# Out:
#      0         jacareacanga 0  Unnamed: 2  BR      1.53E+09   62  -6.22  \
# 0    1         kaitangata 100         NaN  NZ  1.530000e+09   94 -46.28
# 1    2            goulburn 20         NaN  AU  1.530000e+09   91 -34.75
# 2    3                lata 76         NaN  IN  1.530000e+09   89  30.78
# 3    4           chokurdakh 0         NaN  RU  1.530000e+09   88  70.62
# 4    5            martyush 92         NaN  RU  1.530000e+09   94  56.40
# 5    6              hobart 20         NaN  AU  1.530000e+09   87 -42.88
# 6    7          broken hill 0         NaN  AU  1.530000e+09   88 -31.97
# 7    8            harnosand 0         NaN  SE  1.530000e+09   44  62.63
# 8    9            tuatapere 0         NaN  NZ  1.530000e+09  100 -46.13
# 9   10        puerto ayora 90         NaN  EC  1.530000e+09   69  -0.74
# 10  11  havre-saint-pierre 75         NaN  CA  1.530000e+09   58  50.23
# 11  12         punta arenas 0         NaN  CL  1.530000e+09  100 -53.16
# 12  13            tasiilaq 75         NaN  GL  1.530000e+09   60  65.61
# 13  14             chapais 40         NaN  CA  1.530000e+09   38  49.78
# 14  15              avarua 40         NaN  CK  1.530000e+09   56 -21.21
# 15  16                hofn 75         NaN  IS  1.530000e+09   87  64.25
# 16  17        yukamenskoye 92         NaN  RU  1.530000e+09   98  57.89
# 17  18           khandbari 80         NaN  NP  1.530000e+09   67  27.38
# 18  19               bethel 1         NaN  US  1.530000e+09   93  60.79
# 19  20             ushuaia 75         NaN  AR  1.530000e+09   64 -54.81
# 20  21          east london 0         NaN  ZA  1.530000e+09   37 -33.02
# 21  22               bluff 76         NaN  AU  1.530000e+09   76 -23.58
# 22  23           mount isa 75         NaN  AU  1.530000e+09  100 -20.73
# 23  24                pevek 0         NaN  RU  1.530000e+09   71  69.70
# 24  25                 gao 24         NaN  ML  1.530000e+09   16  16.28
# 25  26      cabo san lucas 75         NaN  MX  1.530000e+09   74  22.89
# 26  27           sao filipe 0         NaN  CV  1.530000e+09   88  14.90
# 27  28               tiksi 44         NaN  RU  1.530000e+09   58  71.64
# 28  29           busselton 92         NaN  AU  1.530000e+09  100 -33.64
# 29  30               alofi 76         NaN  NU  1.530000e+09   88 -19.06
# 30  31                 ola 75         NaN  RU  1.530000e+09  100  59.58
# 31  32                atar 20         NaN  MR  1.530000e+09   19  20.52
# 32  33              rikitea 0         NaN  PF  1.530000e+09  100 -23.12
# 33  34             hermanus 0         NaN  ZA  1.530000e+09   24 -34.42
# 34  35       ponta delgada 75         NaN  PT  1.530000e+09   88  37.73
# 35  36             bambari 24         NaN  CF  1.530000e+09   84   5.77
# 36  37      cap malheureux 75         NaN  MU  1.530000e+09   69 -19.98
# 37  38    puerto escondido 75         NaN  MX  1.530000e+09   65  15.86
# 38  39             qaanaaq 32         NaN  GL  1.530000e+09  100  77.48
# 39  40         new norfolk 20         NaN  AU  1.530000e+09   87 -42.78
# 40  41              najran 40         NaN  SA  1.530000e+09   13  17.54
# 41  42        isla mujeres 90         NaN  MX  1.530000e+09  100  21.23
# 42  43        mar del plata 0         NaN  AR  1.530000e+09  100 -46.43
# 43  44          provideniya 0         NaN  RU  1.530000e+09   91  64.42
# 44  45           jamestown 12         NaN  AU  1.530000e+09   88 -33.21
#
#     -57.76    89.6   6.93
# 0   169.85   42.61   5.64
# 1   149.72   44.32  10.11
# 2    78.62   59.89   0.94
# 3   147.90   32.17   2.95
# 4    61.89   55.03   9.33
# 5   147.33   44.60   8.05
# 6   141.45   44.50   7.31
# 7    17.94   60.80  13.87
# 8   167.69   38.92   3.40
# 9   -90.35   77.00  13.87
# 10  -63.60   53.60  19.46
# 11  -70.91   35.60   9.17
# 12  -37.64   39.20   2.24
# 13  -74.86   59.00  10.29
# 14 -159.78   73.40  10.29
# 15  -15.21   51.80   8.05
# 16   52.24   56.65  10.22
# 17   87.21   44.59   1.39
# 18 -161.76   44.60   8.05
# 19  -68.31   41.00   3.36
# 20   27.91   69.80   5.82
# 21  149.07   61.96   4.74
# 22  139.49   64.40   3.29
# 23  170.27   36.94   6.98
# 24   -0.04  110.02   4.97
# 25 -109.91   84.20  10.29
# 26  -24.50   75.73  13.02
# 27  128.87   57.73  10.11
# 28  115.35   60.43  10.56
# 29 -169.92   71.60   3.36
# 30  151.30   42.80   7.76
# 31  -13.05   91.40   9.17
# 32 -134.97   73.57   8.66
# 33   19.24   77.17   8.66
# 34  -25.67   71.60  12.75
# 35   20.68   81.85   7.65
# 36   57.61   75.20  14.99
# 37  -97.07   80.60   3.36
# 38  -69.36   31.45   6.31
# 39  147.06   44.60   8.05
# 40   44.22   98.60  11.41
# 41  -86.73   75.20  16.11
# 42  -67.52   32.53   7.31
# 43 -173.23   40.63  10.78
# 44  138.60   43.15  10.89

# %%
len(df)
# Out:
# 45

# %% [markdown]
# ## Transform

# %%
df['hash'] = pd.Series((hash(tuple(row)) for _, row in df.iterrows()))
#Hash Code
#https://stackoverflow.com/questions/25757042/create-hash-value-for-each-row-of-data-with-selected-columns-in-dataframe-in-pyt
df.head()
# Out:
#    0  jacareacanga 0  Unnamed: 2  BR      1.53E+09  62  -6.22  -57.76   89.6  \
# 0  1  kaitangata 100         NaN  NZ  1.530000e+09  94 -46.28  169.85  42.61
# 1  2     goulburn 20         NaN  AU  1.530000e+09  91 -34.75  149.72  44.32
# 2  3         lata 76         NaN  IN  1.530000e+09  89  30.78   78.62  59.89
# 3  4    chokurdakh 0         NaN  RU  1.530000e+09  88  70.62  147.90  32.17
# 4  5     martyush 92         NaN  RU  1.530000e+09  94  56.40   61.89  55.03
#
#     6.93                 hash
# 0   5.64 -2503469734304243544
# 1  10.11 -5612059781218712084
# 2   0.94 -2322418290265285285
# 3   2.95 -1305015501695499854
# 4   9.33  -375371039485245647

# %%
len(df)
# Out:
# 45

# %%
df_nodupe = df[~df.duplicated()]
#Dedupe code source
#https://stackoverflow.com/questions/40438237/assign-hash-to-row-of-categorical-data-in-pandas

# %%
df_nodupe.head()
# Out:
#    0  jacareacanga 0  Unnamed: 2  BR      1.53E+09  62  -6.22  -57.76   89.6  \
# 0  1  kaitangata 100         NaN  NZ  1.530000e+09  94 -46.28  169.85  42.61
# 1  2     goulburn 20         NaN  AU  1.530000e+09  91 -34.75  149.72  44.32
# 2  3         lata 76         NaN  IN  1.530000e+09  89  30.78   78.62  59.89
# 3  4    chokurdakh 0         NaN  RU  1.530000e+09  88  70.62  147.90  32.17
# 4  5     martyush 92         NaN  RU  1.530000e+09  94  56.40   61.89  55.03
#
#     6.93                 hash
# 0   5.64 -2503469734304243544
# 1  10.11 -5612059781218712084
# 2   0.94 -2322418290265285285
# 3   2.95 -1305015501695499854
# 4   9.33  -375371039485245647

# %%
len(df_nodupe)
# Out:
# 45

# %% [markdown]
# ## Load

# %% [markdown]
# #### > Convert DataFrame to json formatted file

# %%
import json

# %%
df_nodupe.to_json('ETL_json_file', orient='index')
# Converting dataframe data to json format
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_json.html

# %%
json_data = df_nodupe.to_json(orient='index')
parsed = json.loads(json_data)
# print(json.dumps(parsed, indent=4, sort_keys=True))
# Un-comment print to pretty print json formated data

# %% [markdown]
# #### > Create MongoDB named 'etl_db' with a collection 'etl_data'

# %%
import pymongo
from pymongo import MongoClient
client = MongoClient()
client = MongoClient('localhost', 27017)
client = MongoClient('mongodb://localhost:27017/')
print('Mongo version', pymongo.__version__)
# Out:
# Mongo version 3.9.0

# %%
# Uncomment code to drop existing database before creating new one
# client.drop_database('etl_db')

# %%
db = client['etl_db']
# Create database named 'etl_db'

db.etl_data.drop() # Drop collection if it already exist

collection = db['etl_data']
# Create collection called 'etl_data'

# %% [markdown]
# #### > Load ETL_json_file data

# %%
with open('ETL_json_file') as f:
    file_data = json.load(f)
    collection.insert_one(file_data) 
client.close()
# Read json file into mongoDB
# https://stackoverflow.com/questions/49510049/how-to-import-json-file-to-mongodb-using-python
# Out:
# ---------------------------------------------------------------------------
# InvalidDocument                           Traceback (most recent call last)
# <ipython-input-34-e08420b11047> in <module>
#       1 with open('ETL_json_file') as f:
#       2     file_data = json.load(f)
# ----> 3     collection.insert_one(file_data)
#       4 client.close()
#       5 # Read json file into mongoDB
#
# ~\Anaconda3\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation, session)
#     696                          write_concern=write_concern,
#     697                          bypass_doc_val=bypass_document_validation,
# --> 698                          session=session),
#     699             write_concern.acknowledged)
#     700
#
# ~\Anaconda3\lib\site-packages\pymongo\collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     610             return self._insert_one(
#     611                 docs, ordered, check_keys, manipulate, write_concern, op_id,
# --> 612                 bypass_doc_val, session)
#     613
#     614         ids = []
#
# ~\Anaconda3\lib\site-packages\pymongo\collection.py in _insert_one(self, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     598
#     599         self.__database.client._retryable_write(
# --> 600             acknowledged, _insert_command, session)
#     601
#     602         if not isinstance(doc, RawBSONDocument):
#
# ~\Anaconda3\lib\site-packages\pymongo\mongo_client.py in _retryable_write(self, retryable, func, session)
#    1490         """Internal retryable write helper."""
#    1491         with self._tmp_session(session) as s:
# -> 1492             return self._retry_with_session(retryable, func, s, None)
#    1493
#    1494     def _reset_server(self, address):
#
# ~\Anaconda3\lib\site-packages\pymongo\mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1383                             raise last_error
#    1384                         retryable = False
# -> 1385                     return func(session, sock_info, retryable)
#    1386             except ServerSelectionTimeoutError:
#    1387                 if is_retrying():
#
# ~\Anaconda3\lib\site-packages\pymongo\collection.py in _insert_command(session, sock_info, retryable_write)
#     593                 session=session,
#     594                 client=self.__database.client,
# --> 595                 retryable_write=retryable_write)
#     596
#     597             _check_write_command_response(result)
#
# ~\Anaconda3\lib\site-packages\pymongo\pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields)
#     616         # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     617         except BaseException as error:
# --> 618             self._raise_connection_failure(error)
#     619
#     620     def send_message(self, message, max_doc_size):
#
# ~\Anaconda3\lib\site-packages\pymongo\pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields)
#     611                            use_op_msg=self.op_msg_enabled,
#     612                            unacknowledged=unacknowledged,
# --> 613                            user_fields=user_fields)
#     614         except OperationFailure:
#     615             raise
#
# ~\Anaconda3\lib\site-packages\pymongo\network.py in command(sock, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields)
#     127         request_id, msg, size, max_doc_size = message._op_msg(
#     128             flags, spec, dbname, read_preference, slave_ok, check_keys,
# --> 129             codec_options, ctx=compression_ctx)
#     130         # If this is an unacknowledged write then make sure the encoded doc(s)
#     131         # are small enough, otherwise rely on the server to return an error.
#
# ~\Anaconda3\lib\site-packages\pymongo\message.py in _op_msg(flags, command, dbname, read_preference, slave_ok, check_keys, opts, ctx)
#     702                 flags, command, identifier, docs, check_keys, opts, ctx)
#     703         return _op_msg_uncompressed(
# --> 704             flags, command, identifier, docs, check_keys, opts)
#     705     finally:
#     706         # Add the field back to the command.
#
# InvalidDocument: key '1.53E+09' must not contain '.'

# %%
db.list_collection_names()
# List collections in database
# Out:
# []

# %%
db.etl_data.find( { 0: {} } )

# %%
# cursor = db.etl_data # selecting the etl_data collection
# for document in cursor.find():
#    print (document)
# Printing the content of the collection LARGE PRINTOUT

# %% [markdown]
# #### > Reading content of database and loading it into a dataframe

# %%
extracted_etl_data = db.etl_data
df = pd.DataFrame(list(extracted_etl_data.find()))
# https://stackoverflow.com/questions/16249736/how-to-import-data-from-mongodb-to-pandas

# %%
df

# %%
df = df.melt()

# %%
df.head()

# %%
len(df)

# %%
df.iloc[0][1]
# Showing content of first row 'value'

# %% [markdown]
# #### > CSV Move script - moves .csv files after being ETL processed

# %%
import shutil, os, glob

# %%
#For Loop moving all .csv files from the test_input folder 
for filePath in glob.glob('test_input' + '\*.csv'):
            #Move each file to the destination directory
        shutil.move(filePath, 'test_processed');
# Move all files that have been ETL'ed into a processed folder
#Source Code           
#https://thispointer.com/python-how-to-move-files-and-directories/
